# %%
import pandas as pd

# %%
df = pd.read_csv('csv_files/student-scores.csv')
df.head(2)
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
#
#    weekly_self_study_hours career_aspiration  math_score  history_score  \
# 0                       27            Lawyer          73             81
# 1                       47            Doctor          90             86
#
#    physics_score  chemistry_score  biology_score  english_score  \
# 0             93               97             63             80
# 1             96              100             90             88
#
#    geography_score
# 0               87
# 1               90

# %%
df.isna().sum()
# Out:
# id                            0
# first_name                    0
# last_name                     0
# email                         0
# gender                        0
# part_time_job                 0
# absence_days                  0
# extracurricular_activities    0
# weekly_self_study_hours       0
# career_aspiration             0
# math_score                    0
# history_score                 0
# physics_score                 0
# chemistry_score               0
# biology_score                 0
# english_score                 0
# geography_score               0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
df.dtypes
# Out:
# id                             int64
# first_name                    object
# last_name                     object
# email                         object
# gender                        object
# part_time_job                   bool
# absence_days                   int64
# extracurricular_activities      bool
# weekly_self_study_hours        int64
# career_aspiration             object
# math_score                     int64
# history_score                  int64
# physics_score                  int64
# chemistry_score                int64
# biology_score                  int64
# english_score                  int64
# geography_score                int64
# dtype: object

# %%
df.nunique()
# Out:
# id                            2000
# first_name                     453
# last_name                      707
# email                         2000
# gender                           2
# part_time_job                    2
# absence_days                    11
# extracurricular_activities       2
# weekly_self_study_hours         50
# career_aspiration               17
# math_score                      61
# history_score                   51
# physics_score                   50
# chemistry_score                 51
# biology_score                   68
# english_score                   50
# geography_score                 41
# dtype: int64

# %%
scores_col = df.columns[df.columns.str.contains(r'_score$')]
scores_col
# Out:
# Index(['math_score', 'history_score', 'physics_score', 'chemistry_score',
#        'biology_score', 'english_score', 'geography_score'],
#       dtype='object')

# %%
df['average_score'] = sum(df[i] for i in scores_col)/len(scores_col)
df.head(2)
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
#
#    weekly_self_study_hours career_aspiration  math_score  history_score  \
# 0                       27            Lawyer          73             81
# 1                       47            Doctor          90             86
#
#    physics_score  chemistry_score  biology_score  english_score  \
# 0             93               97             63             80
# 1             96              100             90             88
#
#    geography_score  average_score
# 0               87      82.000000
# 1               90      91.428571

# %%
df = df.drop(['id','first_name','last_name','email'],axis=1)
df.head(2)
# Out:
#    gender  part_time_job  absence_days  extracurricular_activities  \
# 0    male          False             3                       False
# 1  female          False             2                       False
#
#    weekly_self_study_hours career_aspiration  math_score  history_score  \
# 0                       27            Lawyer          73             81
# 1                       47            Doctor          90             86
#
#    physics_score  chemistry_score  biology_score  english_score  \
# 0             93               97             63             80
# 1             96              100             90             88
#
#    geography_score  average_score
# 0               87      82.000000
# 1               90      91.428571

# %%
for i in scores_col:
    df = df.drop(i,axis=1)
df.head(2)
# Out:
#    gender  part_time_job  absence_days  extracurricular_activities  \
# 0    male          False             3                       False
# 1  female          False             2                       False
#
#    weekly_self_study_hours career_aspiration  average_score
# 0                       27            Lawyer      82.000000
# 1                       47            Doctor      91.428571

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)  # 1 row, 2 columns, first subplot 
sns.scatterplot(x='absence_days', y='average_score', data=df, color='red')
plt.title('Absence Days vs Average Score')
plt.xlabel('Absence Days')
plt.ylabel('Average Score')

plt.subplot(1, 2, 2)  # 1 row, 2 columns, second subplot
sns.scatterplot(x='weekly_self_study_hours', y='average_score', data=df, color='blue')
plt.title('Weekly Self Study Hours vs Average Score')
plt.xlabel('Weekly Self Study Hours')
plt.ylabel('Average Score')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
numerical   = df.select_dtypes(exclude=['object','bool'])
categorical = df.select_dtypes(exclude=['int64'])

print('Numerical columns :', numerical.columns)
print('categorical columns :', categorical.columns)
# Out:
# Numerical columns : Index(['absence_days', 'weekly_self_study_hours', 'average_score'], dtype='object')
# categorical columns : Index(['gender', 'part_time_job', 'extracurricular_activities',
#        'career_aspiration', 'average_score'],
#       dtype='object')

# %%
categorical.apply(lambda x:x.unique())
# Out:
# gender                                                           [male, female]
# part_time_job                                                     [False, True]
# extracurricular_activities                                        [False, True]
# career_aspiration             [Lawyer, Doctor, Government Officer, Artist, U...
# average_score                 [82.0, 91.42857142857143, 86.42857142857143, 7...
# dtype: object

# %%
numerical.describe()
# Out:
#        absence_days  weekly_self_study_hours  average_score
# count   2000.000000              2000.000000    2000.000000
# mean       3.665500                17.755500      80.980357
# std        2.629271                12.129604       6.042224
# min        0.000000                 0.000000      59.142857
# 25%        2.000000                 5.000000      77.285714
# 50%        3.000000                18.000000      81.000000
# 75%        5.000000                28.000000      84.714286
# max       10.000000                50.000000      96.142857

# %%
x = df.drop('average_score',axis=1)
y = df['average_score']
print(x.shape)
print(y.shape)
# Out:
# (2000, 6)
# (2000,)

# %%
categorical_cols = x.select_dtypes(include=['object','bool']).columns
numerical_cols = x.select_dtypes(include='int64').columns

from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer


preprocessor = ColumnTransformer(
                transformers=[
                    ('numerical', StandardScaler(), numerical_cols),
                    ('categorical', OneHotEncoder(), categorical_cols),
                ]
)

# %%
x_fitted = preprocessor.fit_transform(x)
x_fitted.shape
# Out:
# (2000, 25)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_fitted,y,test_size=0.2,random_state=43)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1600, 25) (1600,)
# (400, 25) (400,)

# %%
import numpy as np 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor


def evaluate(test,pred):
    r2 = r2_score(test,pred)
    mae = mean_absolute_error(test,pred)
    rmse = np.sqrt(mean_squared_error(test,pred))
    return r2,mae,rmse


models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor()
}
results = []
for model_name,model in models.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    r2,mae,rmse = evaluate(y_test,y_pred)
    results.append({'model_name':model_name,
                    'r2' : r2,
                    'mae':mae,
                    'rmse':rmse})

    print(model_name)
    print(f'r2 score : {r2}, MAE : {mae}, RMSE : {rmse}')
# Out:
# Linear Regression
# r2 score : 0.34984369564602746, MAE : 3.7881695247328344, RMSE : 4.7965065779589215
# Lasso
# r2 score : 0.1697378864008705, MAE : 4.324157539650401, RMSE : 5.420305508800771
# Ridge
# r2 score : 0.34978126471936655, MAE : 3.7876376803309437, RMSE : 4.796736863476492
# K-Neighbors Regressor
# r2 score : 0.23462522317826073, MAE : 4.135285714285714, RMSE : 5.204191011255509
# Decision Tree
# r2 score : -0.1607784112081867, MAE : 5.0858928571428565, RMSE : 6.409008041053997
# Random Forest Regressor
# r2 score : 0.19781776866476808, MAE : 4.1153905201247145, RMSE : 5.327858404535567
# XGBRegressor
# r2 score : 0.14718655185032958, MAE : 4.287129859924317, RMSE : 5.493424694308633
# CatBoosting Regressor
# r2 score : 0.29359047877226585, MAE : 3.891465595681991, RMSE : 4.999705543670164
# AdaBoost Regressor
# r2 score : 0.3268491811586499, MAE : 3.817571668648234, RMSE : 4.880590211357077

# %%
pd.DataFrame(results)
# Out:
#                 model_name        r2       mae      rmse
# 0        Linear Regression  0.349844  3.788170  4.796507
# 1                    Lasso  0.169738  4.324158  5.420306
# 2                    Ridge  0.349781  3.787638  4.796737
# 3    K-Neighbors Regressor  0.234625  4.135286  5.204191
# 4            Decision Tree -0.160778  5.085893  6.409008
# 5  Random Forest Regressor  0.197818  4.115391  5.327858
# 6             XGBRegressor  0.147187  4.287130  5.493425
# 7    CatBoosting Regressor  0.293590  3.891466  4.999706
# 8       AdaBoost Regressor  0.326849  3.817572  4.880590

# %% [markdown]
# R2 score is very low

# %%
df['career_aspiration'].unique()
# Out:
# array(['Lawyer', 'Doctor', 'Government Officer', 'Artist', 'Unknown',
#        'Software Engineer', 'Teacher', 'Business Owner', 'Scientist',
#        'Banker', 'Writer', 'Accountant', 'Designer',
#        'Construction Engineer', 'Game Developer', 'Stock Investor',
#        'Real Estate Developer'], dtype=object)

# %%
# Summary table for average_score by career aspiration
summary_table = df.groupby('career_aspiration')['average_score'].describe()

# Show the summary table
print(summary_table)
# Out:
#                        count       mean       std        min        25%  \
# career_aspiration
# Accountant             126.0  79.204082  5.409030  65.142857  75.857143
# Artist                  67.0  80.665245  4.987154  69.142857  77.571429
# Banker                 169.0  81.868977  4.328511  71.142857  79.142857
# Business Owner         309.0  74.483588  5.667884  59.142857  70.142857
# Construction Engineer   68.0  83.470588  4.971626  72.571429  80.250000
# Designer                56.0  82.405612  4.662150  73.571429  79.571429
# Doctor                 119.0  89.678271  3.914037  79.285714  87.000000
# Game Developer          63.0  81.784580  4.188677  72.000000  79.142857
# Government Officer      61.0  80.925059  4.627528  70.142857  78.142857
# Lawyer                 138.0  84.157350  4.072093  70.571429  82.000000
# Real Estate Developer   83.0  79.349398  4.528448  68.428571  76.642857
# Scientist               39.0  86.435897  4.075542  77.000000  84.000000
# ...

# %%
# Violin plot to show the distribution of average_score for each career aspiration
plt.figure(figsize=(12, 6))
sns.violinplot(x='career_aspiration', y='average_score', data=df)

# Title and labels
plt.title('Career Aspiration vs Average Score (Violin Plot)')
plt.xlabel('Career Aspiration')
plt.ylabel('Average Score')

# Rotate the x-axis labels for readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
df.head(2)
# Out:
#    gender  part_time_job  absence_days  extracurricular_activities  \
# 0    male          False             3                       False
# 1  female          False             2                       False
#
#    weekly_self_study_hours career_aspiration  average_score
# 0                       27            Lawyer      82.000000
# 1                       47            Doctor      91.428571

# %%
x = df.drop(['career_aspiration','average_score'],axis=1)
y = df['average_score']

categorical_cols = x.select_dtypes(include=['object','bool']).columns
numerical_cols = x.select_dtypes(include='int64').columns

preprocessor = ColumnTransformer(
                transformers=[
                    ('numerical', StandardScaler(), numerical_cols),
                    ('categorical', OneHotEncoder(), categorical_cols),
                ]
)

x_fitted = preprocessor.fit_transform(x)
x_train,x_test,y_train,y_test = train_test_split(x_fitted,y,test_size=0.2,random_state=43)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1600, 8) (1600,)
# (400, 8) (400,)

# %%
results = []
for model_name,model in models.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    r2,mae,rmse = evaluate(y_test,y_pred)
    results.append({'model_name':model_name,
                    'r2' : r2,
                    'mae':mae,
                    'rmse':rmse})

    # print(model_name)
    # print(f'r2 score : {r2}, MAE : {mae}, RMSE : {rmse}')
pd.DataFrame(results)
# Out:
#                 model_name        r2       mae      rmse
# 0        Linear Regression  0.210763  4.244828  5.284694
# 1                    Lasso  0.169738  4.324158  5.420306
# 2                    Ridge  0.210786  4.244766  5.284617
# 3    K-Neighbors Regressor  0.181365  4.287571  5.382218
# 4            Decision Tree -0.160417  5.074772  6.408009
# 5  Random Forest Regressor  0.129141  4.385680  5.551240
# 6             XGBRegressor  0.084337  4.424601  5.692250
# 7    CatBoosting Regressor  0.251963  4.012867  5.144909
# 8       AdaBoost Regressor  0.286305  3.916772  5.025420

# %%
df.head(2)
# Out:
#    gender  part_time_job  absence_days  extracurricular_activities  \
# 0    male          False             3                       False
# 1  female          False             2                       False
#
#    weekly_self_study_hours career_aspiration  average_score
# 0                       27            Lawyer      82.000000
# 1                       47            Doctor      91.428571

# %%
df.dtypes
# Out:
# gender                         object
# part_time_job                    bool
# absence_days                    int64
# extracurricular_activities       bool
# weekly_self_study_hours         int64
# career_aspiration              object
# average_score                 float64
# dtype: object

# %%
counts = df.select_dtypes(include=['bool']).apply(pd.Series.value_counts)
print(counts)
# Out:
#        part_time_job  extracurricular_activities
# False           1684                        1592
# True             316                         408

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='average_score',bins=30,kde=True,hue='part_time_job')
plt.subplot(122)
sns.histplot(data=df,x='average_score',kde=True,hue='extracurricular_activities')
plt.show()
